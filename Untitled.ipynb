# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# __My name is NOUR__

# %% [markdown]
# *I am interested in data science because i love work with data*

# %% [markdown]
# <h3>in the next cell will do the addition 1 +1  <h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# Table:
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
# numbered list:
# 1. First item
# 2. Second item
# 3. Third item
#
#
# image:
# ![image.png](attachment:5d425a5e-7143-4893-91e6-483efa9d89e4.png)
